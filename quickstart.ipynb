# %%
import os
import pickle
import numpy as np
from utils import mAP_f1_p_fix_r
from utils import evaluate_scenes, predictions_to_scenes
from utils import get_frames, get_batches, scenes2zero_one_representation, visualize_predictions
import ffmpeg
# PT EVALUATION
import os
import pickle

import numpy as np
import torch
from transnetv2.transnetv2_pytorch import TransNetV2
from supernet_flattransf_3_8_8_8_13_12_0_16_60 import TransNetV2Supernet

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# load data & build fnm - path dict
fnm_path_dict = {}
dir_list = [
    "../original_videos/original_videos/",
    "../merged_ads_game_videos/",
    "../merged_video_download/"
]
for cur_dir in dir_list:
    for fnm in os.listdir(cur_dir):
        if fnm.endswith(".mp4"):
            fnm_path_dict[fnm[:-len(".mp4")]] = cur_dir + fnm

# load test annotation keep only one shot
with open('./gt_scenes_dict_baseline_v2.pickle', 'rb') as handle:
    gt_scenes_dict = pickle.load(handle)
handle.close()

print(sum( [len(annot) for _, annot in gt_scenes_dict.items()]))
# Out:
# 2716

# %% [markdown]
# # Load the model

# %%
baseline_model = TransNetV2()
baseline_model.load_state_dict(torch.load('./transnetv2/transnetv2-pytorch-weights.pth'))
baseline_model.eval().cuda()
print("Model loaded")
# Out:
# Model loaded

# %% [markdown]
# # Make prediction

# %%
baseline_one_hot_pred_dict = {}
i = 0
for fnm, annot in gt_scenes_dict.items():
    i += 1
    print(i, fnm)
    
    video_frames, single_frame_predictions, all_frame_predictions = baseline_model.predict_video(fnm_path_dict[fnm])

    baseline_one_hot_pred_dict[fnm] = (single_frame_predictions > 0.5).astype(np.uint8)
# Out:
# 1 31602670982
# [TransNetV2] Extracting frames from ../merged_video_download/31602670982.mp4
# 2 33338203782
# [TransNetV2] Extracting frames from ../original_videos/original_videos/33338203782.mp4
# 3 33803189290
# [TransNetV2] Extracting frames from ../original_videos/original_videos/33803189290.mp4
# 4 34996642719
# [TransNetV2] Extracting frames from ../original_videos/original_videos/34996642719.mp4
# 5 35087786411
# [TransNetV2] Extracting frames from ../original_videos/original_videos/35087786411.mp4
# 6 35219009690
# [TransNetV2] Extracting frames from ../original_videos/original_videos/35219009690.mp4
# 7 35460496768
# [TransNetV2] Extracting frames from ../original_videos/original_videos/35460496768.mp4
# 8 38667643656
# [TransNetV2] Extracting frames from ../merged_video_download/38667643656.mp4
# 9 40355287299
# [TransNetV2] Extracting frames from ../merged_video_download/40355287299.mp4
# 10 41268001962
# [TransNetV2] Extracting frames from ../merged_video_download/41268001962.mp4
# 11 42394122179
# [TransNetV2] Extracting frames from ../merged_video_download/42394122179.mp4
# 12 42728994306
# [TransNetV2] Extracting frames from ../merged_video_download/42728994306.mp4
# 13 43235160681
# [TransNetV2] Extracting frames from ../merged_video_download/43235160681.mp4
# 14 45049694598
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/45049694598.mp4
# 15 46431791499
# [TransNetV2] Extracting frames from ../merged_video_download/46431791499.mp4
# 16 46435147625
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/46435147625.mp4
# 17 47704122306
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/47704122306.mp4
# 18 47957669295
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/47957669295.mp4
# 19 48122821346
# [TransNetV2] Extracting frames from ../merged_video_download/48122821346.mp4
# 20 48168996848
# [TransNetV2] Extracting frames from ../merged_video_download/48168996848.mp4
# 21 48422312550
# [TransNetV2] Extracting frames from ../merged_video_download/48422312550.mp4
# 22 48555393513
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/48555393513.mp4
# 23 48702737472
# [TransNetV2] Extracting frames from ../merged_video_download/48702737472.mp4
# 24 48925830537
# [TransNetV2] Extracting frames from ../merged_video_download/48925830537.mp4
# 25 48938017856
# [TransNetV2] Extracting frames from ../merged_video_download/48938017856.mp4
# 26 49056150592
# [TransNetV2] Extracting frames from ../merged_video_download/49056150592.mp4
# 27 49104256364
# [TransNetV2] Extracting frames from ../merged_video_download/49104256364.mp4
# 28 49127679449
# [TransNetV2] Extracting frames from ../merged_video_download/49127679449.mp4
# 29 49175269235
# [TransNetV2] Extracting frames from ../merged_video_download/49175269235.mp4
# 30 49361878016
# [TransNetV2] Extracting frames from ../merged_video_download/49361878016.mp4
# 31 49751514232
# [TransNetV2] Extracting frames from ../merged_video_download/49751514232.mp4
# 32 49810176625
# [TransNetV2] Extracting frames from ../merged_video_download/49810176625.mp4
# 33 49873920550
# [TransNetV2] Extracting frames from ../merged_video_download/49873920550.mp4
# 34 49968590052
# [TransNetV2] Extracting frames from ../merged_video_download/49968590052.mp4
# 35 49974694347
# [TransNetV2] Extracting frames from ../merged_video_download/49974694347.mp4
# 36 49986240582
# [TransNetV2] Extracting frames from ../merged_video_download/49986240582.mp4
# 37 50162190619
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/50162190619.mp4
# 38 50165129516
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/50165129516.mp4
# 39 50226319770
# [TransNetV2] Extracting frames from ../merged_video_download/50226319770.mp4
# 40 50234611771
# [TransNetV2] Extracting frames from ../merged_video_download/50234611771.mp4
# 41 50270306832
# [TransNetV2] Extracting frames from ../merged_video_download/50270306832.mp4
# 42 50571672955
# [TransNetV2] Extracting frames from ../merged_video_download/50571672955.mp4
# 43 50630424920
# [TransNetV2] Extracting frames from ../merged_video_download/50630424920.mp4
# 44 50681534960
# [TransNetV2] Extracting frames from ../merged_video_download/50681534960.mp4
# 45 50685420175
# [TransNetV2] Extracting frames from ../merged_video_download/50685420175.mp4
# 46 50691559420
# [TransNetV2] Extracting frames from ../merged_video_download/50691559420.mp4
# 47 50722456474
# [TransNetV2] Extracting frames from ../merged_video_download/50722456474.mp4
# 48 50730132874
# [TransNetV2] Extracting frames from ../merged_video_download/50730132874.mp4
# 49 50737710150
# [TransNetV2] Extracting frames from ../merged_video_download/50737710150.mp4
# 50 50747609363
# [TransNetV2] Extracting frames from ../merged_video_download/50747609363.mp4
# 51 50757545897
# [TransNetV2] Extracting frames from ../merged_video_download/50757545897.mp4
# 52 50779805009
# [TransNetV2] Extracting frames from ../merged_video_download/50779805009.mp4
# 53 50790423077
# [TransNetV2] Extracting frames from ../merged_video_download/50790423077.mp4
# 54 50808944385
# [TransNetV2] Extracting frames from ../merged_video_download/50808944385.mp4
# 55 50986712274
# [TransNetV2] Extracting frames from ../merged_video_download/50986712274.mp4
# 56 51017299441
# [TransNetV2] Extracting frames from ../merged_video_download/51017299441.mp4
# 57 51035653483
# [TransNetV2] Extracting frames from ../merged_video_download/51035653483.mp4
# 58 51052713926
# [TransNetV2] Extracting frames from ../merged_video_download/51052713926.mp4
# 59 51131501640
# [TransNetV2] Extracting frames from ../merged_video_download/51131501640.mp4
# 60 51146516534
# [TransNetV2] Extracting frames from ../merged_video_download/51146516534.mp4
# 61 51156423976
# [TransNetV2] Extracting frames from ../merged_video_download/51156423976.mp4
# 62 51174508193
# [TransNetV2] Extracting frames from ../merged_video_download/51174508193.mp4
# 63 51194977739
# [TransNetV2] Extracting frames from ../merged_video_download/51194977739.mp4
# 64 51196454667
# [TransNetV2] Extracting frames from ../merged_video_download/51196454667.mp4
# 65 51358309965
# [TransNetV2] Extracting frames from ../merged_video_download/51358309965.mp4
# 66 51365944152
# [TransNetV2] Extracting frames from ../merged_video_download/51365944152.mp4
# 67 51513541245
# [TransNetV2] Extracting frames from ../merged_video_download/51513541245.mp4
# 68 51557245308
# [TransNetV2] Extracting frames from ../merged_video_download/51557245308.mp4
# 69 51564867434
# [TransNetV2] Extracting frames from ../merged_video_download/51564867434.mp4
# 70 51569443007
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/51569443007.mp4
# 71 51619015176
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/51619015176.mp4
# 72 51640627175
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/51640627175.mp4
# 73 51797484957
# [TransNetV2] Extracting frames from ../merged_video_download/51797484957.mp4
# 74 51801047674
# [TransNetV2] Extracting frames from ../merged_video_download/51801047674.mp4
# 75 51813343076
# [TransNetV2] Extracting frames from ../merged_video_download/51813343076.mp4
# 76 51815641249
# [TransNetV2] Extracting frames from ../merged_video_download/51815641249.mp4
# 77 51821110945
# [TransNetV2] Extracting frames from ../merged_video_download/51821110945.mp4
# 78 51828385722
# [TransNetV2] Extracting frames from ../merged_video_download/51828385722.mp4
# 79 51849706623
# [TransNetV2] Extracting frames from ../merged_video_download/51849706623.mp4
# 80 51850440470
# [TransNetV2] Extracting frames from ../merged_video_download/51850440470.mp4
# 81 51851851628
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/51851851628.mp4
# 82 51853159475
# [TransNetV2] Extracting frames from ../merged_video_download/51853159475.mp4
# 83 51853218995
# [TransNetV2] Extracting frames from ../merged_video_download/51853218995.mp4
# 84 51854738831
# [TransNetV2] Extracting frames from ../merged_video_download/51854738831.mp4
# 85 51856514703
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/51856514703.mp4
# 86 51856804342
# [TransNetV2] Extracting frames from ../merged_video_download/51856804342.mp4
# 87 51863405337
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/51863405337.mp4
# 88 51864484769
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/51864484769.mp4
# 89 51865414031
# [TransNetV2] Extracting frames from ../merged_video_download/51865414031.mp4
# 90 51879134193
# [TransNetV2] Extracting frames from ../merged_video_download/51879134193.mp4
# 91 51883607241
# [TransNetV2] Extracting frames from ../merged_video_download/51883607241.mp4
# 92 51898637293
# [TransNetV2] Extracting frames from ../merged_video_download/51898637293.mp4
# 93 51907740028
# [TransNetV2] Extracting frames from ../merged_video_download/51907740028.mp4
# 94 51909559955
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/51909559955.mp4
# 95 51910832568
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/51910832568.mp4
# 96 51918316554
# [TransNetV2] Extracting frames from ../merged_video_download/51918316554.mp4
# 97 51922596545
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/51922596545.mp4
# 98 51923064451
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/51923064451.mp4
# 99 51923935135
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/51923935135.mp4
# 100 51936013776
# [TransNetV2] Extracting frames from ../merged_video_download/51936013776.mp4
# 101 51962572932
# [TransNetV2] Extracting frames from ../merged_video_download/51962572932.mp4
# 102 51968224744
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/51968224744.mp4
# 103 51970090159
# [TransNetV2] Extracting frames from ../merged_video_download/51970090159.mp4
# 104 51993797249
# [TransNetV2] Extracting frames from ../merged_video_download/51993797249.mp4
# 105 52018429962
# [TransNetV2] Extracting frames from ../merged_video_download/52018429962.mp4
# 106 52019528845
# [TransNetV2] Extracting frames from ../merged_video_download/52019528845.mp4
# 107 52020580256
# [TransNetV2] Extracting frames from ../merged_video_download/52020580256.mp4
# 108 52021424972
# [TransNetV2] Extracting frames from ../merged_video_download/52021424972.mp4
# 109 52036282996
# [TransNetV2] Extracting frames from ../merged_video_download/52036282996.mp4
# 110 52039188217
# [TransNetV2] Extracting frames from ../merged_video_download/52039188217.mp4
# 111 52040994145
# [TransNetV2] Extracting frames from ../merged_video_download/52040994145.mp4
# 112 52065612239
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/52065612239.mp4
# 113 52079863242
# [TransNetV2] Extracting frames from ../merged_video_download/52079863242.mp4
# 114 52088212431
# [TransNetV2] Extracting frames from ../merged_video_download/52088212431.mp4
# 115 52091274367
# [TransNetV2] Extracting frames from ../merged_video_download/52091274367.mp4
# 116 52103654873
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/52103654873.mp4
# 117 52221509412
# [TransNetV2] Extracting frames from ../merged_video_download/52221509412.mp4
# 118 52223316995
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/52223316995.mp4
# 119 52227178506
# [TransNetV2] Extracting frames from ../merged_video_download/52227178506.mp4
# 120 52251949405
# [TransNetV2] Extracting frames from ../merged_video_download/52251949405.mp4
# 121 52265488856
# [TransNetV2] Extracting frames from ../merged_video_download/52265488856.mp4
# 122 52267415630
# [TransNetV2] Extracting frames from ../merged_video_download/52267415630.mp4
# 123 52270627051
# [TransNetV2] Extracting frames from ../merged_video_download/52270627051.mp4
# 124 52285405847
# [TransNetV2] Extracting frames from ../merged_video_download/52285405847.mp4
# 125 52288425765
# [TransNetV2] Extracting frames from ../merged_video_download/52288425765.mp4
# 126 52342275440
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/52342275440.mp4
# 127 52344741598
# [TransNetV2] Extracting frames from ../merged_video_download/52344741598.mp4
# 128 52355335974
# [TransNetV2] Extracting frames from ../merged_video_download/52355335974.mp4
# 129 52402555008
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/52402555008.mp4
# 130 52428336453
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/52428336453.mp4
# 131 52459332798
# [TransNetV2] Extracting frames from ../merged_video_download/52459332798.mp4
# 132 52463663295
# [TransNetV2] Extracting frames from ../merged_video_download/52463663295.mp4
# 133 52465455105
# [TransNetV2] Extracting frames from ../merged_video_download/52465455105.mp4
# 134 52527042670
# [TransNetV2] Extracting frames from ../merged_video_download/52527042670.mp4
# 135 52639473545
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/52639473545.mp4
# 136 52648682110
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/52648682110.mp4
# 137 52660362549
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/52660362549.mp4
# 138 52663756053
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/52663756053.mp4
# 139 52678323813
# [TransNetV2] Extracting frames from ../merged_video_download/52678323813.mp4
# 140 52738625825
# [TransNetV2] Extracting frames from ../merged_video_download/52738625825.mp4
# 141 52774861683
# [TransNetV2] Extracting frames from ../merged_video_download/52774861683.mp4
# 142 52862789455
# [TransNetV2] Extracting frames from ../merged_video_download/52862789455.mp4
# 143 52866623001
# [TransNetV2] Extracting frames from ../merged_video_download/52866623001.mp4
# 144 52905722207
# [TransNetV2] Extracting frames from ../merged_video_download/52905722207.mp4
# 145 52906475525
# [TransNetV2] Extracting frames from ../merged_video_download/52906475525.mp4
# 146 52911335778
# [TransNetV2] Extracting frames from ../merged_video_download/52911335778.mp4
# 147 52955209496
# [TransNetV2] Extracting frames from ../merged_video_download/52955209496.mp4
# 148 52984248093
# [TransNetV2] Extracting frames from ../merged_video_download/52984248093.mp4
# 149 52984250725
# [TransNetV2] Extracting frames from ../merged_video_download/52984250725.mp4
# 150 53080754988
# [TransNetV2] Extracting frames from ../merged_video_download/53080754988.mp4
# 151 53085157367
# [TransNetV2] Extracting frames from ../merged_video_download/53085157367.mp4
# 152 53093515746
# [TransNetV2] Extracting frames from ../merged_video_download/53093515746.mp4
# 153 53094825299
# [TransNetV2] Extracting frames from ../merged_video_download/53094825299.mp4
# 154 53159808242
# [TransNetV2] Extracting frames from ../merged_video_download/53159808242.mp4
# 155 53159810406
# [TransNetV2] Extracting frames from ../merged_video_download/53159810406.mp4
# 156 13335596295
# [TransNetV2] Extracting frames from ../original_videos/original_videos/13335596295.mp4
# 157 17331353453
# [TransNetV2] Extracting frames from ../original_videos/original_videos/17331353453.mp4
# 158 18592632588
# [TransNetV2] Extracting frames from ../original_videos/original_videos/18592632588.mp4
# 159 19079860649
# [TransNetV2] Extracting frames from ../original_videos/original_videos/19079860649.mp4
# 160 20915607770
# [TransNetV2] Extracting frames from ../original_videos/original_videos/20915607770.mp4
# 161 21267401290
# [TransNetV2] Extracting frames from ../original_videos/original_videos/21267401290.mp4
# 162 24881886015
# [TransNetV2] Extracting frames from ../original_videos/original_videos/24881886015.mp4
# 163 25545843427
# [TransNetV2] Extracting frames from ../original_videos/original_videos/25545843427.mp4
# 164 26922743731
# [TransNetV2] Extracting frames from ../original_videos/original_videos/26922743731.mp4
# 165 27107740997
# [TransNetV2] Extracting frames from ../original_videos/original_videos/27107740997.mp4
# 166 27109494185
# [TransNetV2] Extracting frames from ../original_videos/original_videos/27109494185.mp4
# 167 27438014338
# [TransNetV2] Extracting frames from ../original_videos/original_videos/27438014338.mp4
# 168 28251171415
# [TransNetV2] Extracting frames from ../original_videos/original_videos/28251171415.mp4
# 169 28541329142
# [TransNetV2] Extracting frames from ../original_videos/original_videos/28541329142.mp4
# 170 28582983201
# [TransNetV2] Extracting frames from ../original_videos/original_videos/28582983201.mp4
# 171 28855524125
# [TransNetV2] Extracting frames from ../original_videos/original_videos/28855524125.mp4
# 172 29015928124
# [TransNetV2] Extracting frames from ../original_videos/original_videos/29015928124.mp4
# 173 29021603968
# [TransNetV2] Extracting frames from ../original_videos/original_videos/29021603968.mp4
# 174 29047239060
# [TransNetV2] Extracting frames from ../original_videos/original_videos/29047239060.mp4
# 175 29513386332
# [TransNetV2] Extracting frames from ../original_videos/original_videos/29513386332.mp4
# 176 30325167905
# [TransNetV2] Extracting frames from ../original_videos/original_videos/30325167905.mp4
# 177 30382060590
# [TransNetV2] Extracting frames from ../original_videos/original_videos/30382060590.mp4
# 178 30699682698
# [TransNetV2] Extracting frames from ../original_videos/original_videos/30699682698.mp4
# 179 32140458676
# [TransNetV2] Extracting frames from ../original_videos/original_videos/32140458676.mp4
# 180 33442613297
# [TransNetV2] Extracting frames from ../original_videos/original_videos/33442613297.mp4
# 181 35144084768
# [TransNetV2] Extracting frames from ../original_videos/original_videos/35144084768.mp4
# 182 35146145613
# [TransNetV2] Extracting frames from ../original_videos/original_videos/35146145613.mp4
# 183 49921964653
# [TransNetV2] Extracting frames from ../merged_video_download/49921964653.mp4
# 184 50777251302
# [TransNetV2] Extracting frames from ../merged_video_download/50777251302.mp4
# 185 51195576293
# [TransNetV2] Extracting frames from ../merged_video_download/51195576293.mp4
# 186 51666131105
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/51666131105.mp4
# 187 51822315486
# [TransNetV2] Extracting frames from ../merged_video_download/51822315486.mp4
# 188 51974495393
# [TransNetV2] Extracting frames from ../merged_video_download/51974495393.mp4
# 189 51991451479
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/51991451479.mp4
# 190 52058235156
# [TransNetV2] Extracting frames from ../merged_video_download/52058235156.mp4
# 191 52211794196
# [TransNetV2] Extracting frames from ../merged_video_download/52211794196.mp4
# 192 52230867826
# [TransNetV2] Extracting frames from ../merged_video_download/52230867826.mp4
# 193 52231725528
# [TransNetV2] Extracting frames from ../merged_video_download/52231725528.mp4
# 194 52278251659
# [TransNetV2] Extracting frames from ../merged_video_download/52278251659.mp4
# 195 52300997756
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/52300997756.mp4
# 196 52306102332
# [TransNetV2] Extracting frames from ../merged_video_download/52306102332.mp4
# 197 52326893657
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/52326893657.mp4
# 198 52484229807
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/52484229807.mp4
# 199 52541409045
# [TransNetV2] Extracting frames from ../merged_ads_game_videos/52541409045.mp4
# 200 52737439669
# [TransNetV2] Extracting frames from ../merged_video_download/52737439669.mp4

# %%
# with open('../baseline_one_hot_pred_dict_baseline.pickle', 'rb') as handle:
#     baseline_one_hot_pred_dict = pickle.load(handle)
# handle.close()

# %%
mAP, metric_F1, precision, recall, threshold, miou = mAP_f1_p_fix_r(baseline_one_hot_pred_dict, gt_scenes_dict)
print("Baseline 0.5", metric_F1, precision, recall, threshold)
# Out:
# Baseline 0.5 0.7992903082723443 0.9041645760160562 0.7162162162162162 0.9990234375

# %% [markdown]
# # Better Model

# %%
supernet_best_f1 = TransNetV2Supernet().eval()

pretrained_path = os.path.join("../ckpt_0_200_0.pth")
if os.path.exists(pretrained_path):
    print('Loading pretrained_path from %s' % pretrained_path)
    model_dict = supernet_best_f1.state_dict()
    pretrained_dict = torch.load(pretrained_path, map_location=device)
    pretrained_dict = {k: v for k, v in pretrained_dict['net'].items() if k in model_dict}
    print("Current model has %d paras, Update paras %d " % (len(model_dict), len(pretrained_dict)))
    model_dict.update(pretrained_dict)
    supernet_best_f1.load_state_dict(model_dict)
else:
    raise Exception("Error: Can NOT find pretrained best model!!")

supernet_best_f1 = supernet_best_f1.cuda(0)
# Out:
# Loading pretrained_path from ../ckpt_0_200_0.pth
# Current model has 90 paras, Update paras 90

# %%
def cut_video(video_path, frame_ranges):
    # Get the base name of the video file without extension
    base_name = os.path.splitext(os.path.basename(video_path))[0]
    # Create a directory with the same name as the video
    output_dir = os.path.join(os.path.dirname(video_path), base_name)
    os.makedirs(output_dir, exist_ok=True)
    
    # Get the video's frame rate
    probe = ffmpeg.probe(video_path)
    video_streams = [stream for stream in probe['streams'] if stream['codec_type'] == 'video']
    frame_rate = eval(video_streams[0]['r_frame_rate'])
    
    for i, (start_frame, end_frame) in enumerate(frame_ranges):
        start_time = start_frame / frame_rate
        end_time = (end_frame + 1) / frame_rate
        output_file = os.path.join(output_dir, f"{base_name}_part_{i+1}.mp4")
        
        ffmpeg.input(video_path, ss=start_time, to=end_time).output(output_file).run()

    print(f"All video parts have been saved in the folder: {output_dir}")

# %%
def save_images(video_path, frame_ranges, output_dir=None, timeinterval=1):
    # Get the base name of the video file without extension
    base_name = os.path.splitext(os.path.basename(video_path))[0]
    # Use the provided output directory or create one with the same name as the video
    if output_dir is None:
        output_dir = os.path.join(os.path.dirname(video_path), base_name)
    else:
        output_dir = os.path.join(output_dir, base_name)
    
    os.makedirs(output_dir, exist_ok=True)
    
    # Get the video's frame rate
    probe = ffmpeg.probe(video_path)
    video_streams = [stream for stream in probe['streams'] if stream['codec_type'] == 'video']
    frame_rate = eval(video_streams[0]['r_frame_rate'])
    
    for i, (start_frame, end_frame) in enumerate(frame_ranges):
        start_time = start_frame / frame_rate
        end_time = (end_frame + 1) / frame_rate
        segment_duration = end_time - start_time
        
        if segment_duration < timeinterval:
            # Save one image from the middle point if segment is shorter than 500ms
            middle_time = start_time + segment_duration / 2
            output_file = os.path.join(output_dir, f"{base_name}_part_{i+1}_middle.png")
            ffmpeg.input(video_path, ss=middle_time).output(output_file, vframes=1).run()
        else:
            # Save images every 500ms
            current_time = start_time
            img_count = 1
            while current_time < end_time:
                output_file = os.path.join(output_dir, f"{base_name}_part_{i+1}_img_{img_count}.png")
                ffmpeg.input(video_path, ss=current_time).output(output_file, vframes=1).run()
                current_time += timeinterval
                img_count += 1

    print(f"All images have been saved in the folder: {output_dir}")

# %%
# Evaluation
def predict(batch):
    batch = torch.from_numpy(batch.transpose((3, 0, 1, 2))[np.newaxis, ...]) * 1.0
    batch = batch.to(device)
    one_hot = supernet_best_f1(batch)
    if isinstance(one_hot, tuple):
        one_hot = one_hot[0]
    return torch.sigmoid(one_hot[0])

supernet_best_f1_one_hot_pred_dict = {}
i = 0
for fnm, annot in gt_scenes_dict.items():
    i += 1
    print(i, fnm)
    
    predictions = []
    frames = get_frames(fnm_path_dict[fnm])

    for batch in get_batches(frames):
        one_hot = predict(batch)
        one_hot = one_hot.detach().cpu().numpy()
        
        predictions.append(one_hot[25:75])

    predictions = np.concatenate(predictions, 0)[:len(frames)]
    shot_cut = predictions_to_scenes((predictions > np.array([0.5])).astype(np.uint8))
    supernet_best_f1_one_hot_pred_dict[fnm] = shot_cut
    # cut_video(fnm_path_dict[fnm], shot_cut)
    save_images(fnm_path_dict[fnm], shot_cut, './outputs')
    
    break
# Out:
# 1 31602670982
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_1_img_1.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.108x
# video:767kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_1_img_2.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.104x
# video:795kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_1_img_3.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.102x
# video:736kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_2_img_1.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0843x
# video:1261kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_2_img_2.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.08x
# video:1188kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_2_img_3.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0794x
# video:1188kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_3_img_1.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0892x
# video:994kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_3_img_2.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0891x
# video:994kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_4_img_1.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0743x
# video:1437kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_4_img_2.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0745x
# video:1437kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_5_img_1.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0879x
# video:941kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_5_img_2.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0878x
# video:941kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_6_img_1.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0737x
# video:1511kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_6_img_2.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.074x
# video:1498kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_7_img_1.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0796x
# video:1334kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_7_img_2.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0798x
# video:1331kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_8_img_1.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.074x
# video:1473kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_8_img_2.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# ...
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_11_img_1.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0729x
# video:1356kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_11_img_2.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.072x
# video:1440kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_12_img_1.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0792x
# video:1102kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_12_img_2.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0796x
# video:1101kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_13_img_1.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0933x
# video:849kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../merged_video_download/31602670982.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2020-06-28T09:09:14.000000Z
#   Duration: 00:00:24.96, start: 0.000000, bitrate: 8545 kb/s
#     Stream #0:0(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1080x1920, 8197 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : AVC Coding
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './outputs/31602670982/31602670982_part_13_img_2.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1080x1920, q=2-31, 200 kb/s, 59.94 fps, 59.94 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-06-28T09:09:15.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       encoder         : Lavc58.91.100 png
# All images have been saved in the folder: ./outputs/31602670982
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.01 bitrate=N/A speed=0.0939x
# video:849kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
